# %%
import numpy as np
import pandas as pd
import os
import cv2
import matplotlib.pyplot as plt

# %%
datadir_normal="C:\\Users\\user\\Desktop\\project_ball_bearing\\Dataset\\Normal"
datadir_faulty = "C:\\Users\\user\\Desktop\\project_ball_bearing\\Dataset"
categories_normal=["normal_0","normal_1","normal_2","normal_3"]
categories_faulty=["B0007_0","B0007_1","B0007_2","B0007_3","OR007@3_0","OR007@3_1","OR007@3_2","OR007@3_3","OR007@6_0","OR007@6_1","OR007@6_2","OR007@6_3","OR007@12_0","OR007@12_1","OR007@12_2","OR007@12_3","inner_race_0","inner_race_1","inner_race_2","inner_race_3"]

# %%
len(categories_faulty)
# Out:
# 20

# %%
for category in categories_normal:
    path=os.path.join(datadir_normal,category)
    for img in os.listdir(path):
        img_array=cv2.imread(os.path.join(path,img))
        plt.imshow(img_array)
        break
    break

# %%
img_array_new=cv2.resize(img_array,(256,256))

plt.imshow(img_array_new)

# %%
#img_array_new=np.array(img_array_new)

# %%
#img_array_new.shape

# %%
training_data=[]

def create_training_data():
    for category in categories_normal:
        path=os.path.join(datadir_normal,category)
        for img in os.listdir(path):
            img_array=cv2.imread(os.path.join(path,img))
            img_array_new=cv2.resize(img_array,(64,64))
            training_data.append([img_array_new,category])
    for category in categories_faulty:
        path=os.path.join(datadir_faulty,category)
        for img in os.listdir(path):
            img_array=cv2.imread(os.path.join(path,img))
            img_array_new=cv2.resize(img_array,(64,64))
            training_data.append([img_array_new,category])

# %%
create_training_data()

# %%
training_data[0]

# %%
training_data[1]

# %%
# len(training_data)

# %%
#import random

# %%
#random.randint(1,13267)

# %%
training_data_new=[]
for i in range(5710):
    a=random.randint(0,13265)
    training_data_new.append(training_data[a])

# %%
#training_data[100]

# %%
# training_data_new[0]

# %%
#training_data_new[1]

# %%
#len(training_data_new)

# %%
def create_training_data_new():
    for category in categories_new:
        path=os.path.join(datadir_new,category)
        for img in os.listdir(path):
            img_array=cv2.imread(os.path.join(path,img))
            img_array_new=cv2.resize(img_array,(256,256))
            training_data_new.append([img_array_new,0])

# %%
create_training_data_new()

# %%
len(training_data_new)

# %%
X=[]
Y=[]

# %%
for features,labels in training_data:
    X.append(features)
    Y.append(labels)
    
z=np.array(X)

# %%
z.shape

# %%
z.reshape(-1,64,64,3)

# %%
v=np.array(Y)

# %%
v.shape

# %%
v.reshape(-1,1)

# %%
v.shape

# %%
z=z/255.0

# %%
import pickle

pickle_out=open("X.pickle","wb")
pickle.dump(z,pickle_out)
pickle_out.close()

pickle_out=open("Y.pickle","wb")
pickle.dump(v,pickle_out)
pickle_out.close()

# %% [markdown]
# ##
